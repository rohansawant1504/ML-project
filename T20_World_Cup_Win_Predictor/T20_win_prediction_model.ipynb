# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
import pickle

# %%
filenames = []
for file in os.listdir('C:\\Users\\LENOVO\\Desktop\\my project\\T20 World Cup Cricket Score Predictor\\t20s'):
    filenames.append(os.path.join('C:\\Users\\LENOVO\\Desktop\\my project\\T20 World Cup Cricket Score Predictor\\t20s',file))

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
# 100%|█████████▉| 1432/1434 [14:54<00:01,  1.60it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6792/2042649833.py in <module>
#       3 for file in tqdm(filenames):
#       4     with open(file, 'r') as f:
# ----> 5         df = pd.json_normalize(safe_load(f))
#       6         df['match_id'] = counter
#       7         final_df = final_df.append(df)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     421         data = list(data)
#     422     else:
# --> 423         raise NotImplementedError
#     424
#     425     # check to see if a simple recursive function is possible to
#
# NotImplementedError:

# %%
final_df.head(3)
# Out:
#        batting_team  bowling_team       city  runs_left  balls_left  \
# 29512         India  South Africa    Colombo        134         104
# 7366   South Africa      Pakistan  Cape Town         35          25
# 46870     Sri Lanka         India     Mirpur         65          44
#
#        wickets_left  runs_y       crr       rrr  result
# 29512            10     152  6.750000  7.730769       1
# 7366              7     192  9.915789  8.400000       0
# 46870             6     138  5.763158  8.863636       0

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2980/529240141.py in <module>
# ----> 1 final_df.drop(columns=[
#       2     'meta.data_version',
#       3     'meta.created',
#       4     'meta.revision',
#       5     'info.outcome.bowl_out',
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
final_df
# Out:
#        batting_team  bowling_team        city  runs_left  balls_left  \
# 29512         India  South Africa     Colombo        134         104
# 7366   South Africa      Pakistan   Cape Town         35          25
# 46870     Sri Lanka         India      Mirpur         65          44
# 33649  South Africa     Australia   Centurion        108          98
# 6858     Bangladesh         India     Colombo         66          51
# ...             ...           ...         ...        ...         ...
# 8175     Bangladesh   West Indies  Lauderhill         55          30
# 8330     Bangladesh   West Indies  Lauderhill          3           2
# 7592       Pakistan  South Africa   Centurion         74          49
# 34621     Sri Lanka       England      London        174         115
# 7852   South Africa     Sri Lanka   Centurion         68          40
#
#        wickets_left  runs_y        crr        rrr  result
# 29512            10     152   6.750000   7.730769       1
# ...

# %%
final_df['info.gender'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'info.gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# ...

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    966
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    963
# 50      3
# Name: info.overs, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# ...

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
matches = pickle.load(open('dataset_level1.pkl','rb'))
###matches.iloc[0]['innings'][0]['1st innings']['deliveries']

# %%
matches
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#    info.outcome.winner info.player_of_match  \
# 0            Sri Lanka      [DAS Gunaratne]
# 0            Sri Lanka      [DAS Gunaratne]
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
           
        })
    delivery_df = delivery_df.append(loop_df)

# %%
delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0           2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1           2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2           2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3           2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4           2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121       964  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122       964  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123       964  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124       964  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125       964  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue
# ...

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0           2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1           2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2           2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3           2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4           2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121       964  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122       964  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123       964  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124       964  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125       964  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue  \
# ...

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Australia', 'Hong Kong', 'Zimbabwe', 'India', 'Bangladesh',
#        'New Zealand', 'South Africa', 'England', 'West Indies', 'Ireland',
#        'Afghanistan', 'Pakistan', 'United Arab Emirates', 'Scotland',
#        'Oman', 'Papua New Guinea', 'Sri Lanka', 'Netherlands', 'Nepal',
#        'Vanuatu', 'Philippines', 'United States of America', 'Germany',
#        'Ghana', 'Uganda', 'Kenya', 'Namibia', 'Nigeria', 'Botswana',
#        'Guernsey', 'Denmark', 'Jersey', 'Italy', 'Norway', 'Thailand',
#        'Malaysia', 'Maldives', 'Singapore', 'Kuwait', 'Bermuda', 'Canada',
#        'Cayman Islands', 'Portugal', 'Gibraltar', 'Spain', 'Bhutan',
#        'Qatar', 'Iran', 'Belgium', 'Isle of Man', 'Bulgaria', 'Romania'],
#       dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...

# %%
delivery_df1 = delivery_df.merge(matches[['match_id','info.outcome.winner']],left_on='match_id',right_on='match_id')

# %%
delivery_df1
# Out:
#        match_id batting_team  ball        batsman      bowler  runs  \
# 0             2    Australia   0.1       AJ Finch  SL Malinga     0
# 1             2    Australia   0.2       AJ Finch  SL Malinga     0
# 2             2    Australia   0.3       AJ Finch  SL Malinga     1
# 3             2    Australia   0.4      M Klinger  SL Malinga     2
# 4             2    Australia   0.5      M Klinger  SL Malinga     0
# ...         ...          ...   ...            ...         ...   ...
# 47246       961   Bangladesh  14.2    Mahmudullah   JJ Bumrah     2
# 47247       961   Bangladesh  14.3    Mahmudullah   JJ Bumrah     0
# 47248       961   Bangladesh  14.4    Mahmudullah   JJ Bumrah     2
# 47249       961   Bangladesh  14.5    Mahmudullah   JJ Bumrah     1
# 47250       961   Bangladesh  14.6  Sabbir Rahman   JJ Bumrah     1
#
#       player_dismissed    city                          venue bowling_team  \
# ...

# %%
total_run = delivery_df1.groupby(['match_id']).sum()['runs'].reset_index()

# %%
total_run
# Out:
#      match_id  runs
# 0           2   168
# 1           3   173
# 2           4   187
# 3           9   141
# 4          10   195
# ..        ...   ...
# 384       955   147
# 385       957   138
# 386       958   129
# 387       960   150
# 388       961   120
#
# [389 rows x 2 columns]

# %%
delivery_df2 = delivery_df1.merge(total_run[['match_id','runs']],left_on='match_id',right_on='match_id')

# %%
delivery_df2.head(3)
# Out:
#    match_id batting_team  ball   batsman      bowler  runs_x player_dismissed  \
# 0         2    Australia   0.1  AJ Finch  SL Malinga       0                0
# 1         2    Australia   0.2  AJ Finch  SL Malinga       0                0
# 2         2    Australia   0.3  AJ Finch  SL Malinga       1                0
#
#   city                     venue bowling_team info.outcome.winner  runs_y
# 0  NaN  Melbourne Cricket Ground    Sri Lanka           Sri Lanka     168
# 1  NaN  Melbourne Cricket Ground    Sri Lanka           Sri Lanka     168
# 2  NaN  Melbourne Cricket Ground    Sri Lanka           Sri Lanka     168

# %%
output = delivery_df2[['match_id','batting_team','bowling_team','ball','runs_x','player_dismissed','city','venue','runs_y','info.outcome.winner']]

# %%
output
# Out:
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                0
# 1             2    Australia    Sri Lanka   0.2       0                0
# 2             2    Australia    Sri Lanka   0.3       1                0
# 3             2    Australia    Sri Lanka   0.4       2                0
# 4             2    Australia    Sri Lanka   0.5       0                0
# ...         ...          ...          ...   ...     ...              ...
# 47246       961   Bangladesh        India  14.2       2                0
# 47247       961   Bangladesh        India  14.3       0                0
# 47248       961   Bangladesh        India  14.4       2                0
# 47249       961   Bangladesh        India  14.5       1                0
# 47250       961   Bangladesh        India  14.6       1                0
#
#          city                          venue  runs_y info.outcome.winner
# ...

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))

# %% [markdown]
# # Feature Extraction

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                0
# 1             2    Australia    Sri Lanka   0.2       0                0
# 2             2    Australia    Sri Lanka   0.3       1                0
# 3             2    Australia    Sri Lanka   0.4       2                0
# 4             2    Australia    Sri Lanka   0.5       0                0
# ...         ...          ...          ...   ...     ...              ...
# 47246       961   Bangladesh        India  14.2       2                0
# 47247       961   Bangladesh        India  14.3       0                0
# 47248       961   Bangladesh        India  14.4       2                0
# 47249       961   Bangladesh        India  14.5       1                0
# 47250       961   Bangladesh        India  14.6       1                0
#
#          city                          venue  runs_y info.outcome.winner
# ...

# %%
df.isnull().sum()
# Out:
# match_id                  0
# batting_team              0
# bowling_team              0
# ball                      0
# runs_x                    0
# player_dismissed          0
# city                   6440
# venue                     0
# runs_y                    0
# info.outcome.winner    1735
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2467
# Pallekele International Cricket Stadium    1815
# Melbourne Cricket Ground                    971
# Adelaide Oval                               498
# Sharjah Cricket Stadium                     249
# Sydney Cricket Ground                       248
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id                  0
# batting_team              0
# bowling_team              0
# ball                      0
# runs_x                    0
# player_dismissed          0
# city                      0
# venue                     0
# runs_y                    0
# info.outcome.winner    1735
# dtype: int64

# %%
df['info.outcome.winner'].unique()
# Out:
# array(['Sri Lanka', 'Australia', 'Hong Kong', 'New Zealand',
#        'South Africa', 'England', 'West Indies', 'India', 'Afghanistan',
#        nan, 'Scotland', 'Ireland', 'Pakistan', 'United Arab Emirates',
#        'ICC World XI', 'Bangladesh', 'Netherlands', 'Zimbabwe', 'Nepal',
#        'Uganda', 'Nigeria', 'Namibia', 'Kenya', 'Jersey', 'Italy',
#        'Germany', 'Guernsey', 'Malaysia', 'Maldives', 'Qatar',
#        'Singapore', 'Bermuda', 'Canada', 'Oman', 'Papua New Guinea',
#        'Spain', 'Portugal', 'Vanuatu', 'Bahrain', 'Kuwait', 'Belgium',
#        'Bulgaria'], dtype=object)

# %%
df['info.outcome.winner'] = df['info.outcome.winner'].str.replace('United States of America','West Indies')

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
df = df[df['info.outcome.winner'].isin(teams)]

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                0
# 1             2    Australia    Sri Lanka   0.2       0                0
# 2             2    Australia    Sri Lanka   0.3       1                0
# 3             2    Australia    Sri Lanka   0.4       2                0
# 4             2    Australia    Sri Lanka   0.5       0                0
# ...         ...          ...          ...   ...     ...              ...
# 47246       961   Bangladesh        India  14.2       2                0
# 47247       961   Bangladesh        India  14.3       0                0
# 47248       961   Bangladesh        India  14.4       2                0
# 47249       961   Bangladesh        India  14.5       1                0
# 47250       961   Bangladesh        India  14.6       1                0
#
#             city                          venue  runs_y info.outcome.winner
# ...

# %%
df['info.outcome.winner'].unique()
# Out:
# array(['Sri Lanka', 'Australia', 'New Zealand', 'South Africa', 'England',
#        'West Indies', 'India', 'Afghanistan', 'Pakistan', 'Bangladesh'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs_x                 0
# player_dismissed       0
# city                   0
# venue                  0
# runs_y                 0
# info.outcome.winner    0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                0
# 1             2    Australia    Sri Lanka   0.2       0                0
# 2             2    Australia    Sri Lanka   0.3       1                0
# 3             2    Australia    Sri Lanka   0.4       2                0
# 4             2    Australia    Sri Lanka   0.5       0                0
# ...         ...          ...          ...   ...     ...              ...
# 47246       961   Bangladesh        India  14.2       2                0
# 47247       961   Bangladesh        India  14.3       0                0
# 47248       961   Bangladesh        India  14.4       2                0
# 47249       961   Bangladesh        India  14.5       1                0
# 47250       961   Bangladesh        India  14.6       1                0
#
#             city  runs_y info.outcome.winner
# 0      Melbourne     168           Sri Lanka
# ...

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                0
# 1             2    Australia    Sri Lanka   0.2       0                0
# 2             2    Australia    Sri Lanka   0.3       1                0
# 3             2    Australia    Sri Lanka   0.4       2                0
# 4             2    Australia    Sri Lanka   0.5       0                0
# ...         ...          ...          ...   ...     ...              ...
# 47246       961   Bangladesh        India  14.2       2                0
# 47247       961   Bangladesh        India  14.3       0                0
# 47248       961   Bangladesh        India  14.4       2                0
# 47249       961   Bangladesh        India  14.5       1                0
# 47250       961   Bangladesh        India  14.6       1                0
#
#             city  runs_y info.outcome.winner
# 0      Melbourne     168           Sri Lanka
# ...

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs_x']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/4227110397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id').cumsum()['runs_x']

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                0
# 1             2    Australia    Sri Lanka   0.2       0                0
# 2             2    Australia    Sri Lanka   0.3       1                0
# 3             2    Australia    Sri Lanka   0.4       2                0
# 4             2    Australia    Sri Lanka   0.5       0                0
# ...         ...          ...          ...   ...     ...              ...
# 47246       961   Bangladesh        India  14.2       2                0
# 47247       961   Bangladesh        India  14.3       0                0
# 47248       961   Bangladesh        India  14.4       2                0
# 47249       961   Bangladesh        India  14.5       1                0
# 47250       961   Bangladesh        India  14.6       1                0
#
#             city  runs_y info.outcome.winner  current_score
# ...

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/2777558413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/2777558413.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/562775579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                0
# 1             2    Australia    Sri Lanka   0.2       0                0
# 2             2    Australia    Sri Lanka   0.3       1                0
# 3             2    Australia    Sri Lanka   0.4       2                0
# 4             2    Australia    Sri Lanka   0.5       0                0
# ...         ...          ...          ...   ...     ...              ...
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/2304996896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/2304996896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                0
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
df
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/3174236434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/3174236434.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/3174236434.py:3: SettingWithCopyWarning:
# ...

# %%
df['runs_left'] = df['runs_y']-df['current_score']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/2171129107.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runs_left'] = df['runs_y']-df['current_score']

# %%
df['crr'] = (df['current_score']*6)/(120-df['balls_left'])
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/2094531149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/(120-df['balls_left'])

# %%
df['rrr'] = (df['runs_left']*6)/df['balls_left']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/611584998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rrr'] = (df['runs_left']*6)/df['balls_left']

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs_x  player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                 0
# 1             2    Australia    Sri Lanka   0.2       0                 0
# 2             2    Australia    Sri Lanka   0.3       1                 0
# 3             2    Australia    Sri Lanka   0.4       2                 0
# 4             2    Australia    Sri Lanka   0.5       0                 0
# ...         ...          ...          ...   ...     ...               ...
# 47246       961   Bangladesh        India  14.2       2                 5
# 47247       961   Bangladesh        India  14.3       0                 5
# 47248       961   Bangladesh        India  14.4       2                 5
# 47249       961   Bangladesh        India  14.5       1                 5
# 47250       961   Bangladesh        India  14.6       1                 5
#
#             city  runs_y info.outcome.winner  current_score over ball_no  \
# ...

# %%
def result(row):
    return 1 if row['batting_team'] == row['info.outcome.winner'] else 0

# %%
df['result'] = df.apply(result,axis=1)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_2980/3268034411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['result'] = df.apply(result,axis=1)

# %%
df
# Out:
#        match_id batting_team bowling_team  ball  runs_x  player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                 0
# 1             2    Australia    Sri Lanka   0.2       0                 0
# 2             2    Australia    Sri Lanka   0.3       1                 0
# 3             2    Australia    Sri Lanka   0.4       2                 0
# 4             2    Australia    Sri Lanka   0.5       0                 0
# ...         ...          ...          ...   ...     ...               ...
# 47246       961   Bangladesh        India  14.2       2                 5
# 47247       961   Bangladesh        India  14.3       0                 5
# 47248       961   Bangladesh        India  14.4       2                 5
# 47249       961   Bangladesh        India  14.5       1                 5
# 47250       961   Bangladesh        India  14.6       1                 5
#
#             city  runs_y info.outcome.winner  current_score over ball_no  \
# ...

# %%
pickle.dump(df,open('dataset_level3.pkl','wb'))

# %%
df1 = pickle.load(open('dataset_level3.pkl','rb'))

# %%
df1
# Out:
#        match_id batting_team bowling_team  ball  runs_x  player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                 0
# 1             2    Australia    Sri Lanka   0.2       0                 0
# 2             2    Australia    Sri Lanka   0.3       1                 0
# 3             2    Australia    Sri Lanka   0.4       2                 0
# 4             2    Australia    Sri Lanka   0.5       0                 0
# ...         ...          ...          ...   ...     ...               ...
# 47246       961   Bangladesh        India  14.2       2                 5
# 47247       961   Bangladesh        India  14.3       0                 5
# 47248       961   Bangladesh        India  14.4       2                 5
# 47249       961   Bangladesh        India  14.5       1                 5
# 47250       961   Bangladesh        India  14.6       1                 5
#
#             city  runs_y info.outcome.winner  current_score over ball_no  \
# ...

# %%
final_df = df1[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','runs_y','crr','rrr','result']]

# %%
final_df
# Out:
#       batting_team bowling_team       city  runs_left  balls_left  \
# 0        Australia    Sri Lanka  Melbourne        168         119
# 1        Australia    Sri Lanka  Melbourne        168         118
# 2        Australia    Sri Lanka  Melbourne        167         117
# 3        Australia    Sri Lanka  Melbourne        165         116
# 4        Australia    Sri Lanka  Melbourne        165         115
# ...            ...          ...        ...        ...         ...
# 47246   Bangladesh        India     Mirpur          4          34
# 47247   Bangladesh        India     Mirpur          4          33
# 47248   Bangladesh        India     Mirpur          2          32
# 47249   Bangladesh        India     Mirpur          1          31
# 47250   Bangladesh        India     Mirpur          0          30
#
#        wickets_left  runs_y       crr       rrr  result
# 0                10     168  0.000000  8.470588       0
# 1                10     168  0.000000  8.542373       0
# ...

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#       batting_team bowling_team     city  runs_left  balls_left  wickets_left  \
# 40457    Sri Lanka     Pakistan  Colombo         27          11             4
#
#        runs_y       crr        rrr  result
# 40457     172  7.981651  14.727273       1

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets_left    0
# runs_y          0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
final_df
# Out:
#        batting_team  bowling_team          city  runs_left  balls_left  \
# 35758  South Africa   New Zealand    Chittagong        130          83
# 44134  South Africa   Afghanistan        Mumbai        160          90
# 40073   New Zealand  South Africa     Centurion         32          19
# 15639   New Zealand         India  Johannesburg        155          93
# 7317   South Africa      Pakistan     Cape Town        125          73
# ...             ...           ...           ...        ...         ...
# 19071  South Africa       England     Centurion          3           2
# 17353     Australia         India        Mumbai        149         105
# 9527       Pakistan     Australia         Dubai         63          50
# 9849       Pakistan   New Zealand         Dubai        142          94
# 9812    New Zealand      Pakistan         Dubai         26          11
#
#        wickets_left  runs_y        crr        rrr  result
# ...

# %%
final_df.sample()
# Out:
#       batting_team bowling_team    city  runs_left  balls_left  wickets_left  \
# 46883    Sri Lanka        India  Mirpur         47          31             6
#
#        runs_y       crr       rrr  result
# 46883     138  6.134831  9.096774       0

# %%
final_df = final_df[final_df['balls_left']!=0]

# %%
X = final_df.drop(columns=['result'])
y = final_df['result']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#        batting_team bowling_team          city  runs_left  balls_left  \
# 15478   New Zealand    Sri Lanka  Johannesburg         16          11
# 40126      Pakistan   Bangladesh        Mirpur        112          89
# 16089      Pakistan    Sri Lanka  Johannesburg         44          25
# 36684         India    Australia        Mirpur         65          35
# 29456      Pakistan    Australia       Colombo         53          38
# ...             ...          ...           ...        ...         ...
# 43914  South Africa      England        Mumbai        133          78
# 35055   Afghanistan   Bangladesh        Mirpur         15          50
# 9895       Pakistan  New Zealand         Dubai         80          48
# 35482      Pakistan    Australia        Mirpur        177         102
# 18849   New Zealand     Pakistan        London         82         108
#
#        wickets_left  runs_y        crr        rrr
# 15478             5     164   8.146789   8.727273
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear')),
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8915687069314957

# %%
pipe.predict_proba(X_test)[10]
# Out:
# array([0.98772493, 0.01227507])

# %%
#from sklearn.ensemble import RandomForestClassifier

# %%
#pipe = Pipeline(steps=[
 #   ('step1',trf),
  #  ('step2',RandomForestClassifier()),
#])

# %%
#pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', RandomForestClassifier())])

# %%
#y_pred = pipe.predict(X_test)

# %%
#accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
#pipe.predict_proba(X_test)[4]
# Out:
# array([1., 0.])

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','runs_y','crr','rrr','result']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['runs_y'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets_left'].values)
    new_wickets = wickets_left[:]
    new_wickets.insert(0,10)
    wickets_left.append(0)
    w = np.array(wickets_left)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(df1,74,pipe)
temp_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2980/4105450206.py in <module>
# ----> 1 temp_df,target = match_progression(df1,74,pipe)
#       2 temp_df
#
# ~\AppData\Local\Temp/ipykernel_2980/3558457843.py in match_progression(x_df, match_id, pipe)
#       4     temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','runs_y','crr','rrr','result']].dropna()
#       5     temp_df = temp_df[temp_df['balls_left'] != 0]
# ----> 6     result = pipe.predict_proba(temp_df)
#       7     temp_df['lose'] = np.round(result.T[0]*100,1)
#       8     temp_df['win'] = np.round(result.T[1]*100,1)
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in predict_proba(self, X, **predict_proba_params)
#     521         Xt = X
#     522         for _, name, transform in self._iter(with_final=False):
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2980/1972854476.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(18,8))
# ----> 3 plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
#       4 plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
#       5 plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
#
# NameError: name 'temp_df' is not defined

# %%
teams
# Out:
# ['Australia',
#  'India',
#  'Bangladesh',
#  'New Zealand',
#  'South Africa',
#  'England',
#  'West Indies',
#  'Afghanistan',
#  'Pakistan',
#  'Sri Lanka']

# %%
delivery_df['city'].unique()
# Out:
# array([nan, 'Victoria', 'Napier', 'Mount Maunganui', 'Auckland',
#        'Southampton', 'Taunton', 'Cardiff', 'Chester-le-Street', 'Kanpur',
#        'Nagpur', 'Bangalore', 'Lauderhill', 'Abu Dhabi', 'Hobart',
#        'Wellington', 'Hamilton', 'Bloemfontein', 'Potchefstroom',
#        'Barbados', 'Trinidad', 'Colombo', 'St Kitts', 'Jamaica', 'Nelson',
#        'Ranchi', 'Birmingham', 'Manchester', 'Bristol', 'Delhi', 'Rajkot',
#        'Thiruvananthapuram', 'Lahore', 'Johannesburg', 'Centurion',
#        'Cape Town', 'Cuttack', 'Indore', 'Mumbai', 'Dhaka', 'Karachi',
#        'Brisbane', 'Dehradun', 'Sylhet', 'Kolkata', 'Lucknow', 'Chennai',
#        'Gros Islet', 'Basseterre', 'Visakhapatnam', 'Bengaluru',
#        'Adelaide', 'Melbourne', 'Sydney', 'Canberra', 'Perth',
#        'East London', 'Durban', 'Port Elizabeth', 'Chandigarh',
#        'Hyderabad', 'Christchurch', 'Providence', 'Kandy', 'Chattogram',
# ...

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
